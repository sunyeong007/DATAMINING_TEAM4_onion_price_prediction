# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import xgboost as xgb
from sklearn.metrics import mean_squared_error
color_pal = sns.color_palette()
plt.style.use('fivethirtyeight')

from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

# %%
# 데이터 불러오기
df = pd.read_excel('onion_after2013_combined.xlsx')
df.head()
# Out:
#    date_time  상품중품평균가격   자동차용경유  평균풍속(m/s)_통영  일조율(%)_통영  평균풍속(m/s)_울진  \
# 0 2020-01-01   10462.5  1392.26           2.1       80.8           3.4
# 1 2020-01-02   10500.0  1392.88           1.7       78.8           2.9
# 2 2020-01-03   11025.0  1393.16           1.6       78.8           2.6
# 3 2020-01-04   11325.0  1393.82           1.4       79.8           3.2
# 4 2020-01-05   11625.0  1394.03           1.6       74.7           2.2
#
#    일조율(%)_울진  평균풍속(m/s)_여수  일조율(%)_여수  평균기온(℃)  ...  10a당생산량(kg)  month  \
# 0       92.8           4.4       90.9     -4.0  ...         7962      1
# 1       92.8           3.5       86.9     -1.7  ...         7962      1
# 2       91.8           6.3       88.9     -3.5  ...         7962      1
# 3       85.6           4.8       85.9     -2.0  ...         7962      1
# 4       87.6           1.7       82.8     -2.4  ...         7962      1
#
#          생산량(kg)   소비자물가지수    신선야채지수    생활물가지수    식품생활지수  0.5M 평균 습도(%)  \
# 0  111384.166667  0.090000  0.620000  0.360000 -2.060000           51.0
# 1  112483.704301  0.092258  0.511613  0.362258 -2.065161           52.0
# 2  113583.241935  0.094516  0.403226  0.364516 -2.070323           51.0
# 3  114682.779570  0.096774  0.294839  0.366774 -2.075484           53.0
# 4  115782.317204  0.099032  0.186452  0.369032 -2.080645           52.0
#
#    50CM 일 토양수분(%)   얕은평균토양수분
# 0            10.0  17.333333
# 1            10.0  17.333333
# 2            10.0  16.666667
# 3            10.0  16.666667
# 4            10.0  16.666667
#
# [5 rows x 31 columns]

# %%
#df에 year, month 컬럼 추가
df['year'] = pd.DatetimeIndex(df['date_time']).year
df['month'] = pd.DatetimeIndex(df['date_time']).month

# %%
# 1개월 전 해당 일자의 값 -> 가격에 영향 미치는 요인
for col_name in ['생산량(kg)', '소비자물가지수', '신선야채지수', '생활물가지수', '식품생활지수']:
    df1 = df[['date_time', str(col_name)]]

    # date_time을 인덱스로 설정
    df1 = df1.set_index('date_time')
    df1.index = pd.to_datetime(df1.index)

    # 1개월 전 값을 가지도록 31일만큼 데이터 옮김
    df1 = df1[str(col_name)].shift(periods=31, freq='D').reset_index()
    df1 = df1.rename(columns={str(col_name): '1개월전'+str(col_name)})
    df1.head()
    df = pd.merge(df, df1, on=['date_time'], how='left')

# %%
# 1,2개월 전 평균값 -> 가격에 영향 미치는 요인

for i in [2,3]:
    for col_name in ['생산량(kg)', '소비자물가지수', '신선야채지수', '생활물가지수', '식품생활지수']:   
        ##### 각 행에 1,2개월 전의 평균 값 추가하기
        # 새로운 df에 각 월의 평균 값을 구한 후, 값을 한 달씩 뒤로 미룸 -> 전월의 평균값을 나타내도록
        monthly_rainfall_mean2 = df.groupby(pd.Grouper(key='date_time', freq='MS'))[str(col_name)].mean()
        monthly_rainfall_mean2 = monthly_rainfall_mean2.shift(periods=i, freq='M').reset_index()

        # 새로운 df에 year, month 컬럼 추가
        monthly_rainfall_mean2['year'] = pd.DatetimeIndex(monthly_rainfall_mean2['date_time']).year
        monthly_rainfall_mean2['month'] = pd.DatetimeIndex(monthly_rainfall_mean2['date_time']).month

        # 새로 생긴 컬럼 이름을 바꿔줌
        monthly_rainfall_mean2 = monthly_rainfall_mean2.rename(columns={str(col_name): str(i-1)+'개월전평균'+str(col_name)})

        # 새로 만든 컬럼을 연도 및 월을 기준으로 원래 데이터 프레임과 병합
        df = pd.merge(df, monthly_rainfall_mean2, on=['year', 'month'], how='left')

        # 겹치는 date_time 제거
        df = df.rename(columns={'date_time_x': 'date_time'})
        df = df.drop('date_time_y', axis=1)

# %%
# 1,2개월 전 최대값 -> 폭풍, 가뭄과 같이 최대값이 중요한 지표

for i in [2,3]:
    for col_name in ['강수량(mm)', '평균기온(℃)', '평균풍속(m/s)','평균풍속(m/s)_통영','평균풍속(m/s)_울진','평균풍속(m/s)_여수']:   
        ##### 각 행에 1,2개월 전의 최대 값 추가하기
        # 새로운 df에 각 월의 최대 값을 구한 후, 값을 한 달씩 뒤로 미룸 -> 전월의 최대값을 나타내도록
        monthly_rainfall_mean2 = df.groupby(pd.Grouper(key='date_time', freq='MS'))[str(col_name)].max()
        monthly_rainfall_mean2 = monthly_rainfall_mean2.shift(periods=i, freq='M').reset_index()

        # 새로운 df에 year, month 컬럼 추가
        monthly_rainfall_mean2['year'] = pd.DatetimeIndex(monthly_rainfall_mean2['date_time']).year
        monthly_rainfall_mean2['month'] = pd.DatetimeIndex(monthly_rainfall_mean2['date_time']).month

        # 새로 생긴 컬럼 이름을 바꿔줌
        monthly_rainfall_mean2 = monthly_rainfall_mean2.rename(columns={str(col_name): str(i-1)+'개월전최대'+str(col_name)})

        # 새로 만든 컬럼을 연도 및 월을 기준으로 원래 데이터 프레임과 병합
        df = pd.merge(df, monthly_rainfall_mean2, on=['year', 'month'], how='left')

        # 겹치는 date_time 제거
        df = df.rename(columns={'date_time_x': 'date_time'})
        df = df.drop('date_time_y', axis=1)

# %%
# 1,2,3,4,5,6개월 전 평균치 -> 양파 키우는 기간 동안의 기상, 토양, 농기계 경유
 
for i in range(0,6):
    for col_name in ['자동차용경유', '평균습도(%rh)','강수량(mm)', '일조합(hr)', '평균기온(℃)', '일조율(%)', '평균풍속(m/s)',
            '일교차', '0.5M 평균 습도(%)', '얕은평균토양수분']:   
        ##### 각 행에 1,2,3,4,5,6개월 전의 평균 값 추가하기
        # 새로운 df에 각 월의 평균 값을 구한 후, 값을 한 달씩 뒤로 미룸 -> 전월의 평균값을 나타내도록
        monthly_rainfall_mean2 = df.groupby(pd.Grouper(key='date_time', freq='MS'))[str(col_name)].mean()
        monthly_rainfall_mean2 = monthly_rainfall_mean2.shift(periods=i+2, freq='M').reset_index()

        # 새로운 df에 year, month 컬럼 추가
        monthly_rainfall_mean2['year'] = pd.DatetimeIndex(monthly_rainfall_mean2['date_time']).year
        monthly_rainfall_mean2['month'] = pd.DatetimeIndex(monthly_rainfall_mean2['date_time']).month

        # 새로 생긴 컬럼 이름을 바꿔줌
        monthly_rainfall_mean2 = monthly_rainfall_mean2.rename(columns={str(col_name): str(i+1)+'개월전'+str(col_name)})

        # 새로 만든 컬럼을 연도 및 월을 기준으로 원래 데이터 프레임과 병합
        df = pd.merge(df, monthly_rainfall_mean2, on=['year', 'month'], how='left')

        # 겹치는 date_time 제거
        df = df.rename(columns={'date_time_x': 'date_time'})
        df = df.drop('date_time_y', axis=1)

# %%
# 1개월, N년 전 평균 -> 상품중품평균가격

for i in [2,13, 25, 37, 49, 61, 73, 85, 97, 109]:
    for col_name in ['상품중품평균가격']:   
        ##### 각 행에 1개월, N년 전의 평균 값 추가하기
        # 새로운 df에 각 월의 평균 값을 구한 후, 값을 한 달씩 뒤로 미룸 -> 전월의 평균값을 나타내도록
        monthly_rainfall_mean2 = df.groupby(pd.Grouper(key='date_time', freq='MS'))[str(col_name)].mean()
        monthly_rainfall_mean2 = monthly_rainfall_mean2.shift(periods=i, freq='M').reset_index()

        # 새로운 df에 year, month 컬럼 추가
        monthly_rainfall_mean2['year'] = pd.DatetimeIndex(monthly_rainfall_mean2['date_time']).year
        monthly_rainfall_mean2['month'] = pd.DatetimeIndex(monthly_rainfall_mean2['date_time']).month

        # 새로 생긴 컬럼 이름을 바꿔줌
        monthly_rainfall_mean2 = monthly_rainfall_mean2.rename(columns={str(col_name): str(i-1)+'개월전'+str(col_name)})

        # 새로 만든 컬럼을 연도 및 월을 기준으로 원래 데이터 프레임과 병합
        df = pd.merge(df, monthly_rainfall_mean2, on=['year', 'month'], how='left')

        # 겹치는 date_time 제거
        df = df.rename(columns={'date_time_x': 'date_time'})
        df = df.drop('date_time_y', axis=1)

# %%
# 1년 전 재배면적 & 10a당생산량(kg)
   
for col_name in ['재배면적합계(ha)', '10a당생산량(kg)']:   
        ##### 각 행에 1개월, N년 전의 평균 값 추가하기
        # 새로운 df에 각 월의 평균 값을 구한 후, 값을 한 달씩 뒤로 미룸 -> 전월의 평균값을 나타내도록
        monthly_rainfall_mean2 = df.groupby(pd.Grouper(key='date_time', freq='MS'))[str(col_name)].mean()
        monthly_rainfall_mean2 = monthly_rainfall_mean2.shift(periods=13, freq='M').reset_index()

        # 새로운 df에 year 컬럼 추가
        monthly_rainfall_mean2['year'] = pd.DatetimeIndex(monthly_rainfall_mean2['date_time']).year
        monthly_rainfall_mean2['month'] = pd.DatetimeIndex(monthly_rainfall_mean2['date_time']).month

        # 새로 생긴 컬럼 이름을 바꿔줌
        monthly_rainfall_mean2 = monthly_rainfall_mean2.rename(columns={str(col_name): '1년전'+str(col_name)})

        # 새로 만든 컬럼을 연도 및 월을 기준으로 원래 데이터 프레임과 병합
        df = pd.merge(df, monthly_rainfall_mean2, on=['year', 'month'], how='left')

        # 겹치는 date_time 제거
        df = df.rename(columns={'date_time_x': 'date_time'})
        df = df.drop('date_time_y', axis=1)

# %%
df.isnull().sum()
# Out:
# date_time            0
# 상품중품평균가격             0
# 자동차용경유               0
# 평균풍속(m/s)_통영         0
# 일조율(%)_통영            0
#                   ...
# 84개월전상품중품평균가격     1036
# 96개월전상품중품평균가격     1036
# 108개월전상품중품평균가격    1036
# 1년전재배면적합계(ha)      366
# 1년전10a당생산량(kg)     366
# Length: 130, dtype: int64

# %%
df.head()
# Out:
#    date_time  상품중품평균가격   자동차용경유  평균풍속(m/s)_통영  일조율(%)_통영  평균풍속(m/s)_울진  \
# 0 2020-01-01   10462.5  1392.26           2.1       80.8           3.4
# 1 2020-01-02   10500.0  1392.88           1.7       78.8           2.9
# 2 2020-01-03   11025.0  1393.16           1.6       78.8           2.6
# 3 2020-01-04   11325.0  1393.82           1.4       79.8           3.2
# 4 2020-01-05   11625.0  1394.03           1.6       74.7           2.2
#
#    일조율(%)_울진  평균풍속(m/s)_여수  일조율(%)_여수  평균기온(℃)  ...  24개월전상품중품평균가격  \
# 0       92.8           4.4       90.9     -4.0  ...            NaN
# 1       92.8           3.5       86.9     -1.7  ...            NaN
# 2       91.8           6.3       88.9     -3.5  ...            NaN
# 3       85.6           4.8       85.9     -2.0  ...            NaN
# 4       87.6           1.7       82.8     -2.4  ...            NaN
#
#    36개월전상품중품평균가격  48개월전상품중품평균가격  60개월전상품중품평균가격  72개월전상품중품평균가격  84개월전상품중품평균가격  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#    96개월전상품중품평균가격  108개월전상품중품평균가격  1년전재배면적합계(ha)  1년전10a당생산량(kg)
# 0            NaN             NaN            NaN             NaN
# 1            NaN             NaN            NaN             NaN
# 2            NaN             NaN            NaN             NaN
# 3            NaN             NaN            NaN             NaN
# 4            NaN             NaN            NaN             NaN
#
# [5 rows x 130 columns]

# %%
new_df=df.copy()

new_df.head()
# Out:
#    date_time  상품중품평균가격   자동차용경유  평균풍속(m/s)_통영  일조율(%)_통영  평균풍속(m/s)_울진  \
# 0 2020-01-01   10462.5  1392.26           2.1       80.8           3.4
# 1 2020-01-02   10500.0  1392.88           1.7       78.8           2.9
# 2 2020-01-03   11025.0  1393.16           1.6       78.8           2.6
# 3 2020-01-04   11325.0  1393.82           1.4       79.8           3.2
# 4 2020-01-05   11625.0  1394.03           1.6       74.7           2.2
#
#    일조율(%)_울진  평균풍속(m/s)_여수  일조율(%)_여수  평균기온(℃)  ...  24개월전상품중품평균가격  \
# 0       92.8           4.4       90.9     -4.0  ...            NaN
# 1       92.8           3.5       86.9     -1.7  ...            NaN
# 2       91.8           6.3       88.9     -3.5  ...            NaN
# 3       85.6           4.8       85.9     -2.0  ...            NaN
# 4       87.6           1.7       82.8     -2.4  ...            NaN
#
#    36개월전상품중품평균가격  48개월전상품중품평균가격  60개월전상품중품평균가격  72개월전상품중품평균가격  84개월전상품중품평균가격  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#    96개월전상품중품평균가격  108개월전상품중품평균가격  1년전재배면적합계(ha)  1년전10a당생산량(kg)
# 0            NaN             NaN            NaN             NaN
# 1            NaN             NaN            NaN             NaN
# 2            NaN             NaN            NaN             NaN
# 3            NaN             NaN            NaN             NaN
# 4            NaN             NaN            NaN             NaN
#
# [5 rows x 130 columns]

# %%
# new_df['date_time'] = pd.to_datetime(new_df['date_time'])
# # 시간정보 삭제
# new_df['date_time'] = new_df['date_time'].dt.date
# new_df

# new_df = new_df.set_index('date_time')
# new_df
# # date_time을 인덱스로 설정
# # df = df.set_index('date_time')
# # df.index = pd.to_datetime(df.index)
# new_df = new_df.reset_index()
# new_df['date_time'] = pd.to_datetime(new_df['date_time'])

# new_df
new_df = new_df.set_index('date_time')
new_df
# Out:
#             상품중품평균가격   자동차용경유  평균풍속(m/s)_통영  일조율(%)_통영  평균풍속(m/s)_울진  \
# date_time
# 2020-01-01   10462.5  1392.26           2.1       80.8           3.4
# 2020-01-02   10500.0  1392.88           1.7       78.8           2.9
# 2020-01-03   11025.0  1393.16           1.6       78.8           2.6
# 2020-01-04   11325.0  1393.82           1.4       79.8           3.2
# 2020-01-05   11625.0  1394.03           1.6       74.7           2.2
# ...              ...      ...           ...        ...           ...
# 2022-10-28   22340.0  1864.82           2.4       85.3           2.3
# 2022-10-29   22340.0  1866.42           2.5       75.2           1.8
# 2022-10-30   22340.0  1867.15           2.2       62.0           1.6
# 2022-10-31   22340.0  1869.29           3.0       85.2           1.9
# 2022-11-01   22340.0  1872.05           1.7       88.0           2.0
#
#             일조율(%)_울진  평균풍속(m/s)_여수  일조율(%)_여수  평균기온(℃)  최고기온(℃)  ...  \
# date_time                                                         ...
# 2020-01-01       92.8           4.4       90.9     -4.0      0.6  ...
# 2020-01-02       92.8           3.5       86.9     -1.7      3.2  ...
# 2020-01-03       91.8           6.3       88.9     -3.5      3.7  ...
# 2020-01-04       85.6           4.8       85.9     -2.0      6.2  ...
# 2020-01-05       87.6           1.7       82.8     -2.4      5.0  ...
# ...               ...           ...        ...      ...      ...  ...
# 2022-10-28        0.0           2.9       89.0     10.5     19.6  ...
# 2022-10-29       25.0           4.1       84.4     11.7     19.8  ...
# 2022-10-30        4.7           4.5       90.8     11.9     20.3  ...
# 2022-10-31       68.2           4.3       88.9     11.6     19.7  ...
# 2022-11-01       87.9           2.5       88.9     10.5     18.3  ...
#
#             24개월전상품중품평균가격  36개월전상품중품평균가격  48개월전상품중품평균가격  60개월전상품중품평균가격  \
# date_time
# 2020-01-01            NaN            NaN            NaN            NaN
# 2020-01-02            NaN            NaN            NaN            NaN
# 2020-01-03            NaN            NaN            NaN            NaN
# 2020-01-04            NaN            NaN            NaN            NaN
# 2020-01-05            NaN            NaN            NaN            NaN
# ...                   ...            ...            ...            ...
# 2022-10-28   16876.290323            NaN            NaN            NaN
# 2022-10-29   16876.290323            NaN            NaN            NaN
# 2022-10-30   16876.290323            NaN            NaN            NaN
# 2022-10-31   16876.290323            NaN            NaN            NaN
# 2022-11-01   18253.666667            NaN            NaN            NaN
#
#             72개월전상품중품평균가격  84개월전상품중품평균가격  96개월전상품중품평균가격  108개월전상품중품평균가격  \
# date_time
# 2020-01-01            NaN            NaN            NaN             NaN
# 2020-01-02            NaN            NaN            NaN             NaN
# 2020-01-03            NaN            NaN            NaN             NaN
# 2020-01-04            NaN            NaN            NaN             NaN
# 2020-01-05            NaN            NaN            NaN             NaN
# ...                   ...            ...            ...             ...
# 2022-10-28            NaN            NaN            NaN             NaN
# 2022-10-29            NaN            NaN            NaN             NaN
# 2022-10-30            NaN            NaN            NaN             NaN
# 2022-10-31            NaN            NaN            NaN             NaN
# 2022-11-01            NaN            NaN            NaN             NaN
#
#             1년전재배면적합계(ha)  1년전10a당생산량(kg)
# date_time
# 2020-01-01            NaN             NaN
# 2020-01-02            NaN             NaN
# 2020-01-03            NaN             NaN
# 2020-01-04            NaN             NaN
# 2020-01-05            NaN             NaN
# ...                   ...             ...
# 2022-10-28     18461.4043          8541.0
# 2022-10-29     18461.4043          8541.0
# 2022-10-30     18461.4043          8541.0
# 2022-10-31     18461.4043          8541.0
# 2022-11-01     18461.4043          8541.0
#
# [1036 rows x 129 columns]

# %%
from sklearn.model_selection import TimeSeriesSplit

tss = TimeSeriesSplit(n_splits=6, test_size=30, gap=0)
#1달 직후 예측
new_df = new_df.sort_index()

# %%
fig, axs = plt.subplots(6, 1, figsize=(15, 15), sharex=True)

fold = 0
for train_idx, val_idx in tss.split(new_df):
    train = new_df.iloc[train_idx]
    test = new_df.iloc[val_idx]
    train['상품중품평균가격'].plot(ax=axs[fold],
                          label='Training Set',
                          title=f'Data Train/Test Split Fold {fold}')
    test['상품중품평균가격'].plot(ax=axs[fold],
                         label='Test Set')
    axs[fold].axvline(test.index.min(), color='black', ls='--')
    fold += 1
plt.show()

# %%
new_df.head(3)
# Out:
#             상품중품평균가격   자동차용경유  평균풍속(m/s)_통영  일조율(%)_통영  평균풍속(m/s)_울진  \
# date_time
# 2020-01-01   10462.5  1392.26           2.1       80.8           3.4
# 2020-01-02   10500.0  1392.88           1.7       78.8           2.9
# 2020-01-03   11025.0  1393.16           1.6       78.8           2.6
#
#             일조율(%)_울진  평균풍속(m/s)_여수  일조율(%)_여수  평균기온(℃)  최고기온(℃)  ...  \
# date_time                                                         ...
# 2020-01-01       92.8           4.4       90.9     -4.0      0.6  ...
# 2020-01-02       92.8           3.5       86.9     -1.7      3.2  ...
# 2020-01-03       91.8           6.3       88.9     -3.5      3.7  ...
#
#             24개월전상품중품평균가격  36개월전상품중품평균가격  48개월전상품중품평균가격  60개월전상품중품평균가격  \
# date_time
# 2020-01-01            NaN            NaN            NaN            NaN
# 2020-01-02            NaN            NaN            NaN            NaN
# 2020-01-03            NaN            NaN            NaN            NaN
#
#             72개월전상품중품평균가격  84개월전상품중품평균가격  96개월전상품중품평균가격  108개월전상품중품평균가격  \
# date_time
# 2020-01-01            NaN            NaN            NaN             NaN
# 2020-01-02            NaN            NaN            NaN             NaN
# 2020-01-03            NaN            NaN            NaN             NaN
#
#             1년전재배면적합계(ha)  1년전10a당생산량(kg)
# date_time
# 2020-01-01            NaN             NaN
# 2020-01-02            NaN             NaN
# 2020-01-03            NaN             NaN
#
# [3 rows x 129 columns]

# %%
new_df = new_df.reset_index()
new_df['date_time'] = pd.to_datetime(new_df['date_time'])
new_df = new_df.set_index('date_time')

# 달, 주, 일 정보 추가
def create_features(new_df):
    """
    Create time series features based on time series index.
    """
    new_df = new_df.copy()
    new_df['dayofweek'] = new_df.index.dayofweek
    new_df['quarter'] = new_df.index.quarter
    new_df['month'] = new_df.index.month
    new_df['year'] = new_df.index.year
    new_df['dayofyear'] = new_df.index.dayofyear
    new_df['dayofmonth'] = new_df.index.day
    return new_df

new_df = create_features(new_df)

new_df.head(3)
# Out:
#             상품중품평균가격   자동차용경유  평균풍속(m/s)_통영  일조율(%)_통영  평균풍속(m/s)_울진  \
# date_time
# 2020-01-01   10462.5  1392.26           2.1       80.8           3.4
# 2020-01-02   10500.0  1392.88           1.7       78.8           2.9
# 2020-01-03   11025.0  1393.16           1.6       78.8           2.6
#
#             일조율(%)_울진  평균풍속(m/s)_여수  일조율(%)_여수  평균기온(℃)  최고기온(℃)  ...  \
# date_time                                                         ...
# 2020-01-01       92.8           4.4       90.9     -4.0      0.6  ...
# 2020-01-02       92.8           3.5       86.9     -1.7      3.2  ...
# 2020-01-03       91.8           6.3       88.9     -3.5      3.7  ...
#
#             72개월전상품중품평균가격  84개월전상품중품평균가격  96개월전상품중품평균가격  108개월전상품중품평균가격  \
# date_time
# 2020-01-01            NaN            NaN            NaN             NaN
# 2020-01-02            NaN            NaN            NaN             NaN
# 2020-01-03            NaN            NaN            NaN             NaN
#
#             1년전재배면적합계(ha)  1년전10a당생산량(kg)  dayofweek  quarter  dayofyear  \
# date_time
# 2020-01-01            NaN             NaN          2        1          1
# 2020-01-02            NaN             NaN          3        1          2
# 2020-01-03            NaN             NaN          4        1          3
#
#             dayofmonth
# date_time
# 2020-01-01           1
# 2020-01-02           2
# 2020-01-03           3
#
# [3 rows x 133 columns]

# %%
# 하이퍼파라미터 조정(n_estimators=2000) '6개월전자동차용경유'추가
tss = TimeSeriesSplit(n_splits=6, test_size=30*1, gap=0)
new_df = new_df.sort_index()


fold = 0
preds = []
scores = []
for train_idx, val_idx in tss.split(new_df):
    new_df2 = new_df.copy()
    train = new_df.iloc[train_idx]
    test = new_df.iloc[val_idx]

    train = create_features(train)
    test = create_features(test)


    FEATURES = [
          
            '1개월전최대강수량(mm)', '1개월전최대평균기온(℃)','1개월전최대평균풍속(m/s)_여수',
            '2개월전최대강수량(mm)', '2개월전최대평균기온(℃)', '2개월전최대평균풍속(m/s)_여수',
            '생산량(kg)', '1개월전평균생산량(kg)', '2개월전평균생산량(kg)',
        '1개월전자동차용경유', '6개월전자동차용경유',
        
            '1개월전평균기온(℃)','1개월전평균습도(%rh)','1개월전강수량(mm)', 
        '1개월전일조합(hr)','1개월전일조율(%)','1개월전일교차',             
            '1개월전평균풍속(m/s)','1개월전0.5M 평균 습도(%)', '1개월전얕은평균토양수분',
            'month', 'dayofweek', 'quarter', 
            '1개월전평균소비자물가지수', '1개월전평균생활물가지수', 
            '1개월전평균신선야채지수', '1개월전평균식품생활지수',
            '1개월전상품중품평균가격', '12개월전상품중품평균가격', 
            '2개월전얕은평균토양수분','2개월전강수량(mm)','2개월전평균습도(%rh)'
            
            ]
    
    TARGET = '상품중품평균가격'

    X_train = train[FEATURES]
    y_train = train[TARGET]

    X_test = test[FEATURES]
    y_test = test[TARGET]
    
    reg = xgb.XGBRegressor(base_score=0.5, booster='gbtree',    
                       n_estimators=2000,
                       early_stopping_rounds=50,
                       objective='reg:squarederror',
                       max_depth=3,
                       learning_rate=0.01)
    reg.fit(X_train, y_train,
            eval_set=[(X_train, y_train), (X_test, y_test)],
            verbose=100)


    y_pred = reg.predict(X_test)
    preds.append(y_pred)
    score = np.sqrt(mean_squared_error(y_test, y_pred))
    scores.append(score)
    
    test['prediction'] = reg.predict(X_test)
    new_df2 = new_df2.merge(test[['prediction']], how='left', left_index=True, right_index=True)
    ax = new_df2[['상품중품평균가격']].plot(figsize=(15, 5))
    new_df2['prediction'].plot(ax=ax, style='.')
    plt.legend(['Truth Data', 'Predictions'])
    ax.set_title('Raw Dat and Prediction')
    plt.show()
    
    # Create the plot
    fi = pd.DataFrame(data=reg.feature_importances_,
                 index=reg.feature_names_in_,
                 columns=['importance'])

    fi.sort_values('importance').tail(5).plot(kind='barh', title='TOP5 Feature Importance',figsize=(4,4))

    # Display the plot
    plt.show()
# Out:
# [0]	validation_0-rmse:15436.71302	validation_1-rmse:11817.86178
# [100]	validation_0-rmse:5906.73317	validation_1-rmse:4918.67942
# [200]	validation_0-rmse:2529.03317	validation_1-rmse:3072.44864
# [300]	validation_0-rmse:1458.82791	validation_1-rmse:2625.00284
# [400]	validation_0-rmse:1156.26513	validation_1-rmse:2457.60557
# [500]	validation_0-rmse:1002.21523	validation_1-rmse:2322.95195
# [600]	validation_0-rmse:927.67790	validation_1-rmse:2230.52454
# [700]	validation_0-rmse:882.30308	validation_1-rmse:2170.69036
# [800]	validation_0-rmse:822.54219	validation_1-rmse:2152.73701
# [900]	validation_0-rmse:759.37350	validation_1-rmse:2139.00741
# [1000]	validation_0-rmse:716.66841	validation_1-rmse:2124.77382
# [1100]	validation_0-rmse:665.65197	validation_1-rmse:2091.63975
# [1200]	validation_0-rmse:619.36749	validation_1-rmse:2080.78880
# [1300]	validation_0-rmse:579.16886	validation_1-rmse:2063.79652
# [1400]	validation_0-rmse:546.51379	validation_1-rmse:2052.73966
# [1500]	validation_0-rmse:517.70445	validation_1-rmse:2048.84017
# [1600]	validation_0-rmse:493.21792	validation_1-rmse:2048.98181
# [1614]	validation_0-rmse:488.79626	validation_1-rmse:2050.10609
# [0]	validation_0-rmse:15328.58215	validation_1-rmse:19936.48552
# [100]	validation_0-rmse:5875.20490	validation_1-rmse:11119.43987
# [200]	validation_0-rmse:2533.39989	validation_1-rmse:7582.74427
# [300]	validation_0-rmse:1477.73228	validation_1-rmse:5845.55033
# [400]	validation_0-rmse:1172.58514	validation_1-rmse:4714.20413
# [500]	validation_0-rmse:1047.73743	validation_1-rmse:4139.91074
# [600]	validation_0-rmse:953.15333	validation_1-rmse:3887.02498
# [700]	validation_0-rmse:883.07475	validation_1-rmse:3647.33845
# [800]	validation_0-rmse:827.09025	validation_1-rmse:3470.02008
# [900]	validation_0-rmse:771.67849	validation_1-rmse:3380.66253
# [1000]	validation_0-rmse:719.28400	validation_1-rmse:3298.36035
# [1100]	validation_0-rmse:671.19613	validation_1-rmse:3231.93652
# [1200]	validation_0-rmse:626.72774	validation_1-rmse:3204.58280
# [1300]	validation_0-rmse:588.10698	validation_1-rmse:3168.32694
# [1364]	validation_0-rmse:566.10798	validation_1-rmse:3164.16780
# [0]	validation_0-rmse:15498.53639	validation_1-rmse:20831.43906
# [100]	validation_0-rmse:5965.51099	validation_1-rmse:7947.87715
# [200]	validation_0-rmse:2594.54749	validation_1-rmse:3470.57792
# [300]	validation_0-rmse:1509.74094	validation_1-rmse:2057.89081
# [400]	validation_0-rmse:1192.63138	validation_1-rmse:1734.92098
# [500]	validation_0-rmse:1052.81808	validation_1-rmse:1613.78840
# [597]	validation_0-rmse:972.23785	validation_1-rmse:1610.86430
# [0]	validation_0-rmse:15694.40529	validation_1-rmse:21558.03133
# [100]	validation_0-rmse:6049.42783	validation_1-rmse:8945.41634
# [200]	validation_0-rmse:2648.38777	validation_1-rmse:4163.19105
# [300]	validation_0-rmse:1558.30205	validation_1-rmse:2403.53665
# [400]	validation_0-rmse:1227.03532	validation_1-rmse:1653.83320
# [500]	validation_0-rmse:1076.37140	validation_1-rmse:1379.95733
# [600]	validation_0-rmse:981.61555	validation_1-rmse:1162.64180
# [700]	validation_0-rmse:911.58254	validation_1-rmse:1064.35166
# [800]	validation_0-rmse:859.55025	validation_1-rmse:992.63951
# [900]	validation_0-rmse:821.05458	validation_1-rmse:942.33416
# [949]	validation_0-rmse:800.23382	validation_1-rmse:942.29615
# [0]	validation_0-rmse:15905.74727	validation_1-rmse:21505.82606
# [100]	validation_0-rmse:6125.60492	validation_1-rmse:8377.52941
# [200]	validation_0-rmse:2679.73742	validation_1-rmse:3230.51444
# [300]	validation_0-rmse:1551.85242	validation_1-rmse:1110.51404
# [400]	validation_0-rmse:1187.44543	validation_1-rmse:551.97833
# [483]	validation_0-rmse:1075.05164	validation_1-rmse:560.16063
# [0]	validation_0-rmse:16100.41440	validation_1-rmse:21874.84629
# [100]	validation_0-rmse:6180.94345	validation_1-rmse:8524.49806
# [200]	validation_0-rmse:2682.81419	validation_1-rmse:3395.90249
# [300]	validation_0-rmse:1546.88388	validation_1-rmse:1523.05996
# [400]	validation_0-rmse:1172.40706	validation_1-rmse:801.17135
# [500]	validation_0-rmse:1032.34770	validation_1-rmse:521.43372
# [600]	validation_0-rmse:929.25325	validation_1-rmse:421.42316
# [677]	validation_0-rmse:876.61673	validation_1-rmse:410.19659

# %%
# '재배면적합계(ha)','1년전10a당생산량(kg)', '1년전재배면적합계(ha)' 추가
tss = TimeSeriesSplit(n_splits=6, test_size=30*1, gap=0)
new_df = new_df.sort_index()


fold = 0
preds = []
scores = []
for train_idx, val_idx in tss.split(new_df):
    new_df2 = new_df.copy()
    train = new_df.iloc[train_idx]
    test = new_df.iloc[val_idx]

    train = create_features(train)
    test = create_features(test)


    FEATURES = [
          '1개월전평균풍속(m/s)','1개월전최대평균풍속(m/s)','2개월전최대평균풍속(m/s)','1개월전일조율(%)',
            '재배면적합계(ha)','1년전10a당생산량(kg)', '1년전재배면적합계(ha)',
            '생산량(kg)', '1개월전평균생산량(kg)', '2개월전평균생산량(kg)',
            '1개월전평균기온(℃)','1개월전평균습도(%rh)',
            '1개월전최대강수량(mm)', '1개월전최대평균기온(℃)',
            '2개월전최대강수량(mm)', '2개월전최대평균기온(℃)', 
            '1개월전강수량(mm)', '1개월전일조합(hr)','1개월전일교차',             
            '1개월전0.5M 평균 습도(%)', '1개월전얕은평균토양수분',
            'month', 'dayofweek', 'quarter', 
            '1개월전평균소비자물가지수', '1개월전평균생활물가지수', 
            '1개월전평균신선야채지수', '1개월전평균식품생활지수',
            '1개월전상품중품평균가격', '12개월전상품중품평균가격', '24개월전상품중품평균가격', 
            '2개월전얕은평균토양수분','2개월전강수량(mm)','2개월전평균습도(%rh)',
            '1개월전자동차용경유', '6개월전자동차용경유'
            ]
    
    TARGET = '상품중품평균가격'

    X_train = train[FEATURES]
    y_train = train[TARGET]

    X_test = test[FEATURES]
    y_test = test[TARGET]
    
    reg = xgb.XGBRegressor(base_score=0.5, booster='gbtree',    
                       n_estimators=2000,
                       early_stopping_rounds=50,
                       objective='reg:squarederror',
                       max_depth=3,
                       learning_rate=0.01)
    reg.fit(X_train, y_train,
            eval_set=[(X_train, y_train), (X_test, y_test)],
            verbose=100)


    y_pred = reg.predict(X_test)
    preds.append(y_pred)
    score = np.sqrt(mean_squared_error(y_test, y_pred))
    scores.append(score)
    
    test['prediction'] = reg.predict(X_test)
    new_df2 = new_df2.merge(test[['prediction']], how='left', left_index=True, right_index=True)
    ax = new_df2[['상품중품평균가격']].plot(figsize=(15, 5))
    new_df2['prediction'].plot(ax=ax, style='.')
    plt.legend(['Truth Data', 'Predictions'])
    ax.set_title('Raw Dat and Prediction')
    plt.show()
    
    # Create the plot
    fi = pd.DataFrame(data=reg.feature_importances_,
                 index=reg.feature_names_in_,
                 columns=['importance'])

    fi.sort_values('importance').tail(5).plot(kind='barh', title='TOP5 Feature Importance',figsize=(4,4))

    # Display the plot
    plt.show()
# Out:
# [0]	validation_0-rmse:15436.71302	validation_1-rmse:11817.86178
# [100]	validation_0-rmse:5905.85654	validation_1-rmse:4889.25626
# [200]	validation_0-rmse:2528.16197	validation_1-rmse:3077.97508
# [300]	validation_0-rmse:1459.31725	validation_1-rmse:2613.00922
# [400]	validation_0-rmse:1158.68064	validation_1-rmse:2454.83304
# [500]	validation_0-rmse:1001.75425	validation_1-rmse:2324.47181
# [600]	validation_0-rmse:898.43198	validation_1-rmse:2288.23788
# [700]	validation_0-rmse:840.38827	validation_1-rmse:2205.17216
# [800]	validation_0-rmse:781.83609	validation_1-rmse:2179.29526
# [900]	validation_0-rmse:748.56616	validation_1-rmse:2161.29178
# [1000]	validation_0-rmse:710.01286	validation_1-rmse:2145.23236
# [1100]	validation_0-rmse:665.85314	validation_1-rmse:2132.47271
# [1200]	validation_0-rmse:622.57695	validation_1-rmse:2115.02149
# [1300]	validation_0-rmse:584.24350	validation_1-rmse:2103.64776
# [1400]	validation_0-rmse:546.87888	validation_1-rmse:2096.52953
# [1469]	validation_0-rmse:516.98703	validation_1-rmse:2097.01673
# [0]	validation_0-rmse:15328.58215	validation_1-rmse:19936.48552
# [100]	validation_0-rmse:5874.03783	validation_1-rmse:11133.76810
# [200]	validation_0-rmse:2535.29707	validation_1-rmse:7619.68367
# [300]	validation_0-rmse:1478.75719	validation_1-rmse:5863.12400
# [400]	validation_0-rmse:1175.19504	validation_1-rmse:4678.04419
# [500]	validation_0-rmse:1042.29792	validation_1-rmse:4144.25298
# [600]	validation_0-rmse:934.52615	validation_1-rmse:3934.79473
# [700]	validation_0-rmse:867.63813	validation_1-rmse:3705.58628
# [800]	validation_0-rmse:812.57721	validation_1-rmse:3554.45315
# [900]	validation_0-rmse:757.73821	validation_1-rmse:3440.70026
# [1000]	validation_0-rmse:688.49233	validation_1-rmse:3364.05443
# [1100]	validation_0-rmse:643.73154	validation_1-rmse:3295.17264
# [1200]	validation_0-rmse:601.32128	validation_1-rmse:3257.09630
# [1300]	validation_0-rmse:569.34014	validation_1-rmse:3214.12879
# [1400]	validation_0-rmse:545.96261	validation_1-rmse:3173.68676
# [1500]	validation_0-rmse:519.92379	validation_1-rmse:3156.15464
# [1600]	validation_0-rmse:490.99568	validation_1-rmse:3150.91335
# [0]	validation_0-rmse:15498.53639	validation_1-rmse:20831.43906
# [100]	validation_0-rmse:5965.51099	validation_1-rmse:7625.51848
# [200]	validation_0-rmse:2594.54749	validation_1-rmse:2778.60911
# [300]	validation_0-rmse:1491.49241	validation_1-rmse:1014.74545
# [400]	validation_0-rmse:1158.72421	validation_1-rmse:807.47948
# [500]	validation_0-rmse:1004.98124	validation_1-rmse:779.31943
# [529]	validation_0-rmse:964.03877	validation_1-rmse:821.18175
# [0]	validation_0-rmse:15694.40529	validation_1-rmse:21558.03133
# [100]	validation_0-rmse:6049.56918	validation_1-rmse:8920.81811
# [200]	validation_0-rmse:2647.24524	validation_1-rmse:4183.93320
# [300]	validation_0-rmse:1551.26990	validation_1-rmse:2518.69509
# [400]	validation_0-rmse:1203.42955	validation_1-rmse:1960.16949
# [500]	validation_0-rmse:1054.25720	validation_1-rmse:1641.03684
# [600]	validation_0-rmse:960.85113	validation_1-rmse:1366.79627
# [700]	validation_0-rmse:903.75935	validation_1-rmse:1252.10430
# [800]	validation_0-rmse:843.53897	validation_1-rmse:1205.71067
# [900]	validation_0-rmse:791.01671	validation_1-rmse:1169.60821
# [964]	validation_0-rmse:768.48210	validation_1-rmse:1171.84306
# [0]	validation_0-rmse:15905.74727	validation_1-rmse:21503.61999
# [100]	validation_0-rmse:6125.60492	validation_1-rmse:8390.40879
# [200]	validation_0-rmse:2679.73742	validation_1-rmse:2736.01046
# [300]	validation_0-rmse:1551.85242	validation_1-rmse:792.54144
# [370]	validation_0-rmse:1260.96169	validation_1-rmse:814.95561
# [0]	validation_0-rmse:16100.41440	validation_1-rmse:21876.07095
# [100]	validation_0-rmse:6180.94345	validation_1-rmse:8552.84834
# [200]	validation_0-rmse:2682.81419	validation_1-rmse:3420.21651
# [300]	validation_0-rmse:1547.97683	validation_1-rmse:1533.53991
# [400]	validation_0-rmse:1179.47498	validation_1-rmse:823.02791
# [500]	validation_0-rmse:1037.86107	validation_1-rmse:562.01535
# [600]	validation_0-rmse:949.79899	validation_1-rmse:466.07526
# [700]	validation_0-rmse:882.14145	validation_1-rmse:451.53572
# [800]	validation_0-rmse:836.45419	validation_1-rmse:449.56505
# [803]	validation_0-rmse:835.24870	validation_1-rmse:448.63500
