# %%
#-*-coding:utf-8-*-

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import font_manager, rc
font_path = "C:/Windows/Fonts/NGULIM.TTF"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)
color_pal = sns.color_palette()
plt.style.use('fivethirtyeight')

# %%
weather_df = pd.read_excel('weather_after2020.xlsx')

weather_df
# Out:
#              일시  평균풍속(m/s)_통영  일조율(%)_통영  평균풍속(m/s)_울진  일조율(%)_울진  \
# 0    2020-01-01           2.1       80.8           3.4       92.8
# 1    2020-01-02           1.7       78.8           2.9       92.8
# 2    2020-01-03           1.6       78.8           2.6       91.8
# 3    2020-01-04           1.4       79.8           3.2       85.6
# 4    2020-01-05           1.6       74.7           2.2       87.6
# ...         ...           ...        ...           ...        ...
# 1031 2022-10-28           2.4       85.3           2.3        0.0
# 1032 2022-10-29           2.5       75.2           1.8       25.0
# 1033 2022-10-30           2.2       62.0           1.6        4.7
# 1034 2022-10-31           3.0       85.2           1.9       68.2
# 1035 2022-11-01           1.7       88.0           2.0       87.9
#
#       평균풍속(m/s)_여수  일조율(%)_여수  평균기온(℃)  최고기온(℃)  최저기온(℃)   일교차  강수량(mm)  \
# 0              4.4       90.9     -4.0      0.6     -7.5   8.1      0.1
# ...

# %%
# # 평균풍속, 평균일조율을 새로운 컬럼으로 추가하기
# weather_df['평균풍속(m/s)'] = weather_df[['평균풍속(m/s)_통영', '평균풍속(m/s)_울진', '평균풍속(m/s)_여수']].mean(axis=1)
# weather_df['일조율(%)'] = weather_df[['일조율(%)_통영', '일조율(%)_울진', '일조율(%)_여수']].mean(axis=1)


# 일시 통일
weather_df = weather_df.rename(columns={'일시': 'date_time'})

weather_df.head()
# Out:
#    date_time  평균풍속(m/s)_통영  일조율(%)_통영  평균풍속(m/s)_울진  일조율(%)_울진  평균풍속(m/s)_여수  \
# 0 2020-01-01           2.1       80.8           3.4       92.8           4.4
# 1 2020-01-02           1.7       78.8           2.9       92.8           3.5
# 2 2020-01-03           1.6       78.8           2.6       91.8           6.3
# 3 2020-01-04           1.4       79.8           3.2       85.6           4.8
# 4 2020-01-05           1.6       74.7           2.2       87.6           1.7
#
#    일조율(%)_여수  평균기온(℃)  최고기온(℃)  최저기온(℃)   일교차  강수량(mm)  평균습도(%rh)  최저습도(%rh)  \
# 0       90.9     -4.0      0.6     -7.5   8.1      0.1       79.1         52
# 1       86.9     -1.7      3.2     -5.1   8.3      0.0       83.4         66
# 2       88.9     -3.5      3.7     -8.8  12.5      0.0       78.6         40
# 3       85.9     -2.0      6.2     -8.3  14.5      0.0       73.6         39
# 4       82.8     -2.4      5.0     -9.2  14.2      0.0       71.0         37
#
#    일조합(hr)  일조율(%)  평균풍속(m/s)
# ...

# %%
# 날짜 범위가 '2020-01-01'에서 '2022-11-01'인 새 데이터 프레임 생성
new_date_range = pd.date_range(start='2020-01-01', end='2022-11-01', name='date_time')
new_withnull_df = pd.DataFrame({'date_time': new_date_range})

# 새 데이터 프레임을 기존 데이터 프레임과 병합
weather_df = pd.merge(new_withnull_df, weather_df, on='date_time', how='left')

# date_time을 기준으로 데이터 프레임 정렬
weather_df = weather_df.sort_values('date_time').reset_index(drop=True)

# %%
weather_df.isnull().sum()
# 원본데이터 null 값 존재하지 않음
# Out:
# date_time       0
# 평균풍속(m/s)_통영    0
# 일조율(%)_통영       0
# 평균풍속(m/s)_울진    0
# 일조율(%)_울진       0
# 평균풍속(m/s)_여수    0
# 일조율(%)_여수       0
# 평균기온(℃)         0
# 최고기온(℃)         0
# 최저기온(℃)         0
# 일교차             0
# 강수량(mm)         0
# 평균습도(%rh)       0
# 최저습도(%rh)       0
# 일조합(hr)         0
# 일조율(%)          0
# 평균풍속(m/s)       0
# dtype: int64

# %%
#### 기온 plot

# 원하는 너비 및 높이 설정
fig, ax = plt.subplots(figsize=(15, 6))

# plot 표시
ax.plot(weather_df['date_time'], weather_df['평균기온(℃)'], 'r')
ax.plot(weather_df['date_time'], weather_df['최고기온(℃)'], 'g')
ax.plot(weather_df['date_time'], weather_df['최저기온(℃)'], 'b')
ax.plot(weather_df['date_time'], weather_df['일교차'], 'y')

# 플롯 제목 및 범례 설정
ax.set_title('기온')
ax.legend(['평균기온(℃)', '최고기온(℃)', '최저기온(℃)', '일교차'])

# 플롯 표시
plt.show()

# %%
#### 강수량 plot

# 원하는 너비 및 높이 설정
fig, ax = plt.subplots(figsize=(15, 6))

# plot 표시
ax.plot(weather_df['date_time'], weather_df['강수량(mm)'], 'b')

# 플롯 제목 및 범례 설정
ax.set_title('강수량')
ax.legend(['강수량(mm)'])

# 플롯 표시
plt.show()

# %%
#### 습도 plot

# 원하는 너비 및 높이 설정
fig, ax = plt.subplots(figsize=(15, 6))

# plot 표시
ax.plot(weather_df['date_time'], weather_df['평균습도(%rh)'], 'g')
ax.plot(weather_df['date_time'], weather_df['최저습도(%rh)'], 'b')

# 플롯 제목 및 범례 설정
ax.set_title('습도')
ax.legend(['평균습도(%rh)', '최저습도(%rh)'])

# 플롯 표시
plt.show()

# %%
weather_df.columns
# Out:
# Index(['date_time', '평균풍속(m/s)_통영', '일조율(%)_통영', '평균풍속(m/s)_울진', '일조율(%)_울진',
#        '평균풍속(m/s)_여수', '일조율(%)_여수', '평균기온(℃)', '최고기온(℃)', '최저기온(℃)', '일교차',
#        '강수량(mm)', '평균습도(%rh)', '최저습도(%rh)', '일조합(hr)', '일조율(%)', '평균풍속(m/s)'],
#       dtype='object')

# %%
#### 일조합&일조율 plot

# 원하는 너비 및 높이 설정
fig, ax = plt.subplots(figsize=(15, 6))

# plot 표시
ax.plot(weather_df['date_time'], weather_df['일조합(hr)'], 'ro')
ax.plot(weather_df['date_time'], weather_df['일조율(%)'], 'go')

# 플롯 제목 및 범례 설정
ax.set_title('일조합&일조율')
ax.legend(['일조합(hr)', '일조율(%)'])

# 플롯 표시
plt.show()

# %%
#### 평균풍속 plot

# 원하는 너비 및 높이 설정
fig, ax = plt.subplots(figsize=(15, 6))

# plot 표시
ax.plot(weather_df['date_time'], weather_df['평균풍속(m/s)'], 'b')

# 플롯 제목 및 범례 설정
ax.set_title('평균풍속')
ax.legend(['평균풍속(m/s)'])

# 플롯 표시
plt.show()

# %%
#### 지역별 평균풍속 plot

# 원하는 너비 및 높이 설정
fig, ax = plt.subplots(figsize=(15, 6))

# plot 표시
ax.plot(weather_df['date_time'], weather_df['평균풍속(m/s)_여수'], 'r')
ax.plot(weather_df['date_time'], weather_df['평균풍속(m/s)_통영'], 'b')
ax.plot(weather_df['date_time'], weather_df['평균풍속(m/s)_울진'], 'g')

# 플롯 제목 및 범례 설정
ax.set_title('지역별 평균풍속')
ax.legend(['평균풍속(m/s)_통영', '평균풍속(m/s)_울진', '평균풍속(m/s)_여수'])

# 플롯 표시
plt.show()

# %%
#### 일조율 plot

# 원하는 너비 및 높이 설정
fig, ax = plt.subplots(figsize=(15, 6))

# plot 표시
ax.plot(weather_df['date_time'], weather_df['일조율(%)'], 'b')

# 플롯 제목 및 범례 설정
ax.set_title('일조율')
ax.legend(['일조율(%)'])

# 플롯 표시
plt.show()

# %%
weather_df = weather_df.set_index('date_time')
weather_df.head()
# Out:
#             평균풍속(m/s)_통영  일조율(%)_통영  평균풍속(m/s)_울진  일조율(%)_울진  평균풍속(m/s)_여수  \
# date_time
# 2020-01-01           2.1       80.8           3.4       92.8           4.4
# 2020-01-02           1.7       78.8           2.9       92.8           3.5
# 2020-01-03           1.6       78.8           2.6       91.8           6.3
# 2020-01-04           1.4       79.8           3.2       85.6           4.8
# 2020-01-05           1.6       74.7           2.2       87.6           1.7
#
#             일조율(%)_여수  평균기온(℃)  최고기온(℃)  최저기온(℃)   일교차  강수량(mm)  평균습도(%rh)  \
# date_time
# 2020-01-01       90.9     -4.0      0.6     -7.5   8.1      0.1       79.1
# 2020-01-02       86.9     -1.7      3.2     -5.1   8.3      0.0       83.4
# 2020-01-03       88.9     -3.5      3.7     -8.8  12.5      0.0       78.6
# 2020-01-04       85.9     -2.0      6.2     -8.3  14.5      0.0       73.6
# 2020-01-05       82.8     -2.4      5.0     -9.2  14.2      0.0       71.0
#
# ...

# %%
weather_df.to_excel(excel_writer='weather_df_after2020.xlsx', sheet_name='weather_df_after2020')
